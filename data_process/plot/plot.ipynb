# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_input.csv')  
  
# 将 "Loss" 列中的 "-" 替换为 "0:0"  
df['Loss'] = df['Loss'].replace('-', '0:0')  
  
# 将 "Loss" 列中的比值转换为浮点数  
df['Loss'] = df['Loss'].apply(lambda x: eval(x.replace(':', '/')))  
  
# 绘制 ta_text 和 ta_image 随 Loss 变化的曲线  
plt.figure(figsize=(10, 6))  
plt.plot(df['Loss'], df['ta_text'], marker='o', label='TA Text')  
plt.plot(df['Loss'], df['ta_image'], marker='o', label='TA Image')  
  
plt.xlabel('Loss Weight')  
plt.ylabel('TA Value')  
plt.title('TA Text and TA Image vs Loss Weight')  
plt.legend()  
plt.grid(True)  
plt.savefig("ta_vs_lossweight.pdf")  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 11
#       8 df['Loss'] = df['Loss'].replace('-', '0:0')
#      10 # 将 "Loss" 列中的比值转换为浮点数
# ---> 11 df['Loss'] = df['Loss'].apply(lambda x: eval(x.replace(':', '/')))
#      13 # 绘制 ta_text 和 ta_image 随 Loss 变化的曲线
#      14 plt.figure(figsize=(10, 6))
#
# File ~/miniconda3/envs/llama_factory/lib/python3.10/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
# ...

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp.csv')  
  
# 创建一个新的列 'Index' 作为横坐标（行号）  
df['Index'] = range(len(df))  
  
# 绘制 ta_text 和 ta_image 随 Index 变化的曲线  
plt.figure(figsize=(10, 6))  
plt.plot(df['Index'], df['ta_text'], marker='o', label='TA Text')  
plt.plot(df['Index'], df['ta_image'], marker='o', label='TA Image')  
  
plt.xlabel('Index')  
plt.ylabel('TA Value')  
plt.title('TA Text and TA Image vs Index')  
plt.legend()  
plt.grid(True)  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp.csv')  
  
# 创建一个新的列 'Index' 作为横坐标（行号）  
df['Index'] = range(len(df))  
  
# 设置图表大小  
plt.figure(figsize=(12, 8))  
  
# 绘制各列随 Index 变化的曲线  
columns_to_plot = ['ta_text', 'ta_image', 'alpaca_eval_lcwin', 'arena-hard_gpt4o', 'mt-bench', 'mmlu']  
for column in columns_to_plot:  
    plt.plot(df['Index'], df[column], marker='o', label=column)  
  
# 设置图表标题和标签  
plt.xlabel('Index')  
plt.ylabel('Value')  
plt.title('Various Metrics vs Index')  
plt.legend()  
plt.grid(True)  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_instruct.csv')  
  
# 创建一个新的列 'Index' 作为横坐标（行号）  
df['Index'] = range(len(df))  
  
# 设置图表大小  
plt.figure(figsize=(12, 8))  
  
# 绘制各列随 Index 变化的曲线  
columns_to_plot = ['ta_text', 'ta_image', 'alpaca_eval_lcwin', 'arena-hard_gpt4o', 'mt-bench', 'mmlu']  
for column in columns_to_plot:  
    plt.plot(df['Index'], df[column], marker='o', label=column)  
  
# 设置图表标题和标签  
plt.xlabel('Index')  
plt.ylabel('Value')  
plt.title('Various Metrics vs Index')  
plt.legend()  
plt.grid(True)  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_instruct.csv')  
  
# 创建一个新的列 'Index' 作为横坐标（行号）  
df['Index'] = range(len(df))  
  
# 绘制 ta_text 和 ta_image 随 Index 变化的曲线  
plt.figure(figsize=(10, 6))  
plt.plot(df['Index'], df['ta_text'], marker='o', label='TA Text')  
plt.plot(df['Index'], df['ta_image'], marker='o', label='TA Image')  
  
plt.xlabel('Index')  
plt.ylabel('TA Value')  
plt.title('TA Text and TA Image vs Index')  
plt.legend()  
plt.grid(True)  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['Loss'] = df['Loss'].apply(loss_to_denominator)  
  
# 设置图表大小  
plt.figure(figsize=(12, 8))  
  
# 绘制各列随 Loss 分母变化的曲线  
columns_to_plot = ['ta_text', 'ta_image', 'alpaca_eval_lcwin', 'arena-hard_gpt4o', 'mt-bench', 'mmlu']  
for column in columns_to_plot:  
    plt.plot(df['Loss'], df[column], marker='o', label=column)  
  
# 设置图表标题和标签  
plt.xlabel('Loss Denominator')  
plt.ylabel('Value')  
plt.title('Various Metrics vs Loss Denominator')  
plt.legend()  
plt.grid(True)  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_instruct.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['Loss'] = df['Loss'].apply(loss_to_denominator)  
  
# 设置图表大小  
plt.figure(figsize=(12, 8))  
  
# 绘制各列随 Loss 分母变化的曲线  
columns_to_plot = ['ta_text', 'ta_image', 'alpaca_eval_lcwin', 'arena-hard_gpt4o', 'mt-bench', 'mmlu']  
for column in columns_to_plot:  
    plt.plot(df['Loss'], df[column], marker='o', label=column)  
  
# 设置图表标题和标签  
plt.xlabel('Loss Denominator')  
plt.ylabel('Value')  
plt.title('Various Metrics vs Loss Denominator')  
plt.legend()  
plt.grid(True)  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_instruct.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['Loss'] = df['Loss'].apply(loss_to_denominator)  
  
# 设置图表大小  
plt.figure(figsize=(12, 8))  
  
# 绘制各列随 Loss 分母变化的曲线  
columns_to_plot = ['ta_text', 'ta_image', 'alpaca_eval_lcwin', 'arena-hard_gpt4o', 'mt-bench', 'mmlu']  
for column in columns_to_plot:  
    plt.plot(df['Loss'], df[column], marker='o', label=column)  
  
# 设置图表标题和标签  
plt.xlabel('w2:w1')  
plt.ylabel('Score')  
plt.title('Various Metrics vs w2:w1')  
plt.legend()  
plt.grid(True)  
  
# 保存图表为高分辨率的PDF文件  
plt.savefig('metrics_vs_w2_w1.pdf', dpi=300, bbox_inches='tight')  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_instruct.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['Loss'] = df['Loss'].apply(loss_to_denominator)  
  
# 设置图表大小  
plt.figure(figsize=(12, 8))  
  
# 绘制各列随 Loss 分母变化的曲线  
columns_to_plot = ['ta_text', 'ta_image']  
for column in columns_to_plot:  
    plt.plot(df['Loss'], df[column], marker='o', label=column)  
  
# 设置图表标题和标签  
plt.xlabel('w2:w1')  
plt.ylabel('Score')  
plt.title('Various Metrics vs w2:w1')  
plt.legend()  
plt.grid(True)  
  
# 保存图表为高分辨率的PDF文件  
plt.savefig('metrics_vs_w2_w1.pdf', dpi=300, bbox_inches='tight')  
  
# 显示图表  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/llama/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Loss'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 11
#       8 def loss_to_denominator(loss_str):
# ...

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns  
# 读取CSV文件  
df = pd.read_csv('weight_exp.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['DPO Loss'] = df['DPO Loss'].apply(loss_to_denominator)  
  
# 设置Seaborn风格  
sns.set(style="whitegrid")  
  
# 设置图表大小  
plt.figure(figsize=(10, 6))  
  
# 绘制各列随 Loss 分母变化的曲线  
# columns_to_plot = ['TA Text', 'TA Image', "AlpacaEval 2.0", "Arena-Hard", "MT-Bench"]  
columns_to_plot = ['TA Text', 'TA Image']
markers = ['o', 's']  # 定义每条线的标记样式  
colors = ['#1f77b4', '#ff7f0e']  # 定义每条线的颜色  
  
for column, marker, color in zip(columns_to_plot, markers, colors):  
    plt.plot(df['DPO Loss'], df[column], marker=marker, label=column, color=color, linestyle='-', linewidth=2, markersize=8)  
  
# 设置图表标题和标签  
plt.xlabel('w2:w1 Ratio', fontsize=14)  # 改进后的x轴标签  
plt.ylabel('TA Score', fontsize=14)  # 改进后的y轴标签  
plt.title('TA Scores vs w2:w1 Ratio', fontsize=16)  # 改进后的标题  
plt.legend(fontsize=12)  
plt.grid(True, linestyle='--', alpha=0.7)  
  
# 设置刻度字体大小  
plt.xticks(fontsize=12)  
plt.yticks(fontsize=12)  
  
# 保存图表为高分辨率的PDF文件  
plt.savefig('ta_scores_vs_w2_w1_ratio_base.pdf', dpi=300, bbox_inches='tight')  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['DPO Loss'] = df['DPO Loss'].apply(loss_to_denominator)  
  
# 设置Seaborn风格  
sns.set(style="whitegrid")  
  
# 设置图表大小  
plt.figure(figsize=(10, 6))  
  
# 绘制各列随 Loss 分母变化的曲线  

columns_to_plot = ['TA Text', 'TA Image', "Arena-Hard"]  
markers = ['o', 's', '^', 'd', 'x']  # 定义每条线的标记样式  
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']  # 定义每条线的颜色  
  
for column, marker, color in zip(columns_to_plot, markers, colors):  
    plt.plot(df['DPO Loss'], df[column], marker=marker, label=column, color=color, linestyle='-', linewidth=2, markersize=8)  
  
# 设置图表标题和标签  
plt.xlabel('w2:w1 Ratio', fontsize=14)  # 改进后的x轴标签  
plt.ylabel('TA Score', fontsize=14)  # 改进后的y轴标签  
plt.title('Llama3.1-8B-Base TA Scores vs w2:w1 Ratio', fontsize=16)  # 改进后的标题  
plt.legend(fontsize=12)  
plt.grid(True, linestyle='--', alpha=0.7)  
  
# 设置刻度字体大小  
plt.xticks(fontsize=12)  
plt.yticks(fontsize=12)  
  
# 保存图表为高分辨率的PDF文件  
plt.savefig('ta_scores_vs_w2_w1_ratio_base.pdf', dpi=300, bbox_inches='tight')  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_instruct.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['DPO Loss'] = df['DPO Loss'].apply(loss_to_denominator)  
  
# 设置Seaborn风格  
sns.set(style="whitegrid")  
  
# 设置图表大小  
plt.figure(figsize=(10, 6))  
  
# 绘制各列随 Loss 分母变化的曲线  
columns_to_plot = ['TA Text', 'TA Image',"Arena-Hard"]  

markers = ['o', 's', '^', 'd', 'x']  # 定义每条线的标记样式  
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']  # 定义每条线的颜色  
  
for column, marker, color in zip(columns_to_plot, markers, colors):  
    plt.plot(df['DPO Loss'], df[column], marker=marker, label=column, color=color, linestyle='-', linewidth=2, markersize=8)  
  
# 设置图表标题和标签  
plt.xlabel('w2:w1 Ratio', fontsize=14)  # 改进后的x轴标签  
plt.ylabel('TA Score', fontsize=14)  # 改进后的y轴标签  
plt.title('Llama3.1-8B-Instruct TA Scores vs w2:w1 Ratio', fontsize=16)  # 改进后的标题  
plt.legend(fontsize=12)  
plt.grid(True, linestyle='--', alpha=0.7)  
  
# 设置刻度字体大小  
plt.xticks(fontsize=12)  
plt.yticks(fontsize=12)  
  
# 保存图表为高分辨率的PDF文件  
plt.savefig('ta_scores_vs_w2_w1_ratio.pdf', dpi=300, bbox_inches='tight')  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_instruct.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['DPO Loss'] = df['DPO Loss'].apply(loss_to_denominator)  
  
# 设置Seaborn风格  
sns.set(style="whitegrid")  
  
# 设置图表大小  
plt.figure(figsize=(10, 6))  
  
# 绘制各列随 Loss 分母变化的曲线  
columns_to_plot = ['TA Text', 'TA Image']  
markers = ['o', 's']  # 定义每条线的标记样式  
colors = ['#1f77b4', '#ff7f0e']  # 定义每条线的颜色  
  
for column, marker, color in zip(columns_to_plot, markers, colors):  
    plt.plot(df['DPO Loss'], df[column], marker=marker, label=column, color=color, linestyle='-', linewidth=2, markersize=8)  
  
# 设置图表标题和标签  
plt.xlabel('w2:w1', fontsize=14)  
plt.ylabel('Score', fontsize=14)  
plt.title('Various Metrics vs w2:w1', fontsize=16)  
plt.legend(fontsize=12)  
plt.grid(True, linestyle='--', alpha=0.7)  
  
# 设置刻度字体大小  
plt.xticks(fontsize=12)  
plt.yticks(fontsize=12)  
  
# 保存图表为高分辨率的PDF文件  
plt.savefig('metrics_vs_w2_w1.pdf', dpi=300, bbox_inches='tight')  
  
# 显示图表  
plt.show()

# %%
import pandas as pd  
import matplotlib.pyplot as plt  
import seaborn as sns  
  
# 读取CSV文件  
df = pd.read_csv('weight_exp_instruct.csv')  
  
# 将 "Loss" 列中的比值转换为分母的数值  
def loss_to_denominator(loss_str):  
    return float(loss_str.split(':')[1])  
  
df['DPO Loss'] = df['DPO Loss'].apply(loss_to_denominator)  
  
# 设置Seaborn风格  
sns.set(style="whitegrid")  
  
# 设置图表大小  
plt.figure(figsize=(10, 6))  
  
# 绘制各列随 Loss 分母变化的曲线  
columns_to_plot = ['TA Text', 'TA Image']  
markers = ['o', 's']  # 定义每条线的标记样式  
colors = ['#1f77b4', '#ff7f0e']  # 定义每条线的颜色  
  
for column, marker, color in zip(columns_to_plot, markers, colors):  
    plt.plot(df['DPO Loss'], df[column], marker=marker, label=column, color=color, linestyle='-', linewidth=2, markersize=8)  
  
# 设置图表标题和标签  
plt.xlabel('w2:w1 Ratio', fontsize=14)  # 改进后的x轴标签  
plt.ylabel('TA Score', fontsize=14)  # 改进后的y轴标签  
plt.title('TA Scores vs w2:w1 Ratio', fontsize=16)  # 改进后的标题  
plt.legend(fontsize=12)  
plt.grid(True, linestyle='--', alpha=0.7)  
  
# 设置刻度字体大小  
plt.xticks(fontsize=12)  
plt.yticks(fontsize=12)  
  
# 保存图表为高分辨率的PDF文件  
plt.savefig('ta_scores_vs_w2_w1_ratio.pdf', dpi=1000, bbox_inches='tight')  
  
# 显示图表  
plt.show()
